# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LDPC_study/blob/main/corrected_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
%(N,K) LDPC code에서 N은 code word, K는 message
k=input('enter the length of Msg Word:');
n=input('enter the length of codeword:');
P=input('enter the parity matrix :')

m=input('enter the Msg word:')
C=encode(m,n,k,'linear',G)
D=decode(C, n, k, 'linear',G)

H=[P' eye(n-k)]
dtable=syndtable(H)
R=input('Enter the received codeword');

S_B=rem(R*H',2)
S_D=bi2de(S_B,'left-msb')
# %bi2de : (Not recommended) Convert Binary to Base-P
S_D2=bi2de(S_B)

E=dtable(S_D+1,:)
#E=[0 1 0 0 0 0]
CC=R+E
#CC=[1 1 1 1 0 0]

#Enter the received codeword[1 0 1 1 0 0]으로 설정하였기에,
#원래 값의 경우 2번째 element의 경우 0으로 error가 존재한다.
#이를 나타내기위해서 E=[0 1 0 0 0 0]를 사용하였고, 수신 된 값인 R과
#E를 더하여, CC인 수정된 codeword값이 구해서 오류없는 값을 구할 수 있다.

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)
