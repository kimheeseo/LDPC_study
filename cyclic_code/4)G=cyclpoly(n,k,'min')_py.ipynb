# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LDPC_study/blob/main/4)G%3Dcyclpoly(n%2Ck%2C'min')_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
%출처 : https://youtu.be/1Xj9gAMcZQg
clc;
clear all;

k=input('enter the length of Msg word :');
n=input('enter the length of codeword :');
m=input('enter the Msg Word :');
G=cyclpoly(n,k,'min')

gx=poly2sym(G) 
#계수로 구성된 벡터에서 기호 다항식 생성

#p = poly2sym(c)
#계수로 구성된 벡터 c에서 기호 다항식 p를 만듭니다.

# %% [markdown]
# ![5.JPG](data:image/jpeg;base64,...)
