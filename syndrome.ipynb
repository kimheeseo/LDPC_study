# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LDPC_study/blob/main/syndrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#(N,K) LDPC code에서 N은 code word, K는 message
k=input('enter the length of Msg Word:');
n=input('enter the length of codeword:');
P=input('enter the parity matrix :')

m=input('enter the Msg word:')
C=encode(m,n,k,'linear',G)
D=decode(C, n, k, 'linear',G)

H=[P' eye(n-k)]
R=input('enter the received codeword'); 
S=R*H'

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %%
#위의 코드에서 S는 신드롬을 나타내는 데, 신드롬의 값에 따라 error를 확인할 수 있다.
#H인 parity check matrix, G인 generator matrix를 순서대로 따라왔으면 알 수 있을 것이고,
#이제 R:[1 0 1 1 0 0]*H^T를 하면 [3 1 2]가 나오는 데, 이값을 mod2로 값을 구하면, [1 1 0]으로
#이 값은 H의 2번째열과 같은 값으로 R의 2번째가 error임을 알 수 있는데, 원래 codeword가 [1 1 1 1 0 0]이였기에,
#이 값과 비교하면 C:[1 1 1 1 0 0]과 R;[1 0 1 1 0 0]과 2번째 요소에서 1과 0로 차이나는 것을 알 수 있다.
