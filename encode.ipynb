# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LDPC_study/blob/main/encode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %%
%그냥 encode하면 위와 같은 오류가 생기는데, 저 중에 하나를 설치해야한다.
%저는 Communications Toolbox를 설치하였습니다.

%(N,K) LDPC code에서 N은 code word, K는 message
k=input('enter the length of Msg Word :');
n=input('enter the length of codeword :');
P=input('enter the parity matrix :')

G=[eye(k) P]
m=input('enter the Msg word:')
C=encode(m,n,k,'linear',G)

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)![3.JPG](data:image/jpeg;base64,...)![2.JPG](data:image/jpeg;base64,...)

# %%
%우선 N=6, K=3으로 설정하여, (N,K)=(6,3)이 된다.
%다음으로 parity matrix를 [1 1 1;1 1 0;1 0 1]으로 설정하였기에,
%한국말로 생성행렬, Generator matrix는 위의 식처럼 구성이 되는데,
# %G=(K)*(N)인데, 위의 경우도 3*6이 되는 것을 통해 확인할 수 있다.

%이제 codeword를 구해야하는 데, 우선 G는 만들어졌고, message를 [1 1 1] (1*3)으로 설정하면,
# %m : (1*3) * G : (3*6) = C : (1*6)이 되고 그 값은 [1 1 1 1 0 0]이 된다. 이때, 앞의 [1 1 1]은 message
%뒤의 [1 0 0]은 parity check matrix임을 확인할 수 있다.
