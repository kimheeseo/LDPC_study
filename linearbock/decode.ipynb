# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LDPC_study/blob/main/decode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#(N,K) LDPC code에서 N은 code word, K는 message
k=input('enter the length of Msg Word:');
n=input('enter the length of codeword:');
P=input('enter the parity matrix :')

m=input('enter the Msg word:')
C=encode(m,n,k,'linear',G)
D=decode(C, n, k, 'linear',G)

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %%
#앞서 C인 codeword가 [1 1 1 1 0 0]을 구했는데, 이것은 decode하여, 원래의 보낸 메시지인 [1 1 1]를 구한다.
