# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LDPC_study/blob/main/random_normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 출처 : https://wotres.tistory.com/entry/tfrandomnormal-%EC%82%AC%EC%9A%A9%EB%B2%95

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220527125636.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)?

# %%
# !pip install tensorflow==1.15
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 412.3 MB 24 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 22.7 MB/s
# ...
#      |████████████████████████████████| 50 kB 9.4 MB/s
# ...
#      |████████████████████████████████| 503 kB 74.8 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=c8f2685b0ce0b4982a822d9411599d7be6f85415499f9164a330be06657f97fd
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
sess=tf.Session()
x=tf.Variable(tf.random_normal([784, 200], mean=1, stddev = 0.35))
init=tf.global_variables_initializer()
sess.run(init)
print(sess.run(x))
# Out:
# [[0.85801005 1.0684379  0.87767386 ... 0.86434245 0.33303142 1.1868899 ]
#  [1.3299482  1.3198128  0.54842603 ... 0.9064787  1.3365656  0.8827837 ]
#  [1.2176198  0.8750035  0.96009773 ... 1.0620518  0.83763134 0.92805994]
#  ...
#  [0.75303155 0.88853776 1.7498914  ... 0.58826935 0.8548484  0.6348915 ]
#  [1.1320744  0.8462819  1.0694839  ... 0.6524154  0.5660904  0.64608073]
#  [0.8412492  1.1119283  1.2424831  ... 1.3240472  0.8293464  1.5391939 ]]

# %%
y=sess.run(x)
print("y값",y)
#tf.truncated_normal(shape, mean=0.0, stddev=1.0, dtype=tf.float32, seed=None, name=None)
#출처 : https://tensorflowkorea.gitbooks.io/tensorflow-kr/content/g3doc/api_docs/python/constant_op.html
# Out:
# y값 [[0.85801005 1.0684379  0.87767386 ... 0.86434245 0.33303142 1.1868899 ]
#  [1.3299482  1.3198128  0.54842603 ... 0.9064787  1.3365656  0.8827837 ]
#  [1.2176198  0.8750035  0.96009773 ... 1.0620518  0.83763134 0.92805994]
#  ...
#  [0.75303155 0.88853776 1.7498914  ... 0.58826935 0.8548484  0.6348915 ]
#  [1.1320744  0.8462819  1.0694839  ... 0.6524154  0.5660904  0.64608073]
#  [0.8412492  1.1119283  1.2424831  ... 1.3240472  0.8293464  1.5391939 ]]

# %%
import matplotlib.pyplot as plt
plt.plot(y)

# %%
x=y[0]
print("y[0]값",y[0])
# Out:
# y[0]값 [ 0.85801005  1.0684379   0.87767386  0.77246     0.62416726  0.74304426
#   0.90255415  0.8347299   0.8300925   0.98050636  1.0287403   1.2065192
#   0.87750703  1.1904571   1.543658    1.0055497   1.8528564   1.1821696
#   0.53135806  1.1003581   0.62127346  1.0260293   0.93529814  0.6447486
#   0.98163146  1.0287634   1.0626438   0.977855    1.525337    1.3788829
#   0.7737622   0.90976316  1.3641196   0.7493575   1.3939348   0.92112666
#   1.0286471   1.9412029   0.9811866   1.0810016   0.9095682   1.0183667
#   1.3266691   0.9521197   1.313939    0.698123    1.8391726   0.5965587
#   1.3322767   1.161967    0.70149505  0.65116143  0.6572537   1.4941273
#   1.2867086   1.3563168   1.4239146   0.10453612  0.8760067   1.5393686
#   1.4557294   0.89949894  0.76075184  1.3516021   1.408799    0.79021454
#   0.47689068  1.2848018   0.93448883  1.3471644   1.268836    0.6975528
#   0.7084074   1.0775398   0.64452827  1.2661691   1.3598326   0.8066316
# ...

# %%
y.shape
# Out:
# (784, 200)

# %%
plt.plot(x) #y[1]

# %%
z=y[783]
plt.plot(z)

# %%
sess=tf.Session()
x=tf.Variable(tf.random_normal([784, 2], mean=0, stddev = 0.35))
init=tf.global_variables_initializer()
sess.run(init)
print(sess.run(x))
# Out:
# [[ 0.525814   -0.3396296 ]
#  [ 0.17654037 -0.28682435]
#  [-0.12980406 -0.03620249]
#  ...
#  [-0.16958337 -0.16340888]
#  [-0.3318838   0.03045904]
#  [ 0.324237   -0.05850488]]

# %%
y=sess.run(x)
x1=y[0]
print("y[0]값",y[0])
# Out:
# y[0]값 [ 0.525814  -0.3396296]

# %%
ha=[]
haha=[]
for i in range(784) :
  ha.append(y[i][0])
for i in range(784) :
  haha.append(y[i][1])

# %%
y.shape
# Out:
# (784, 2)

# %%
plt.plot()

# %%
y1=y.reshape(1,1568)
y1
# Out:
# array([[ 0.525814  , -0.3396296 ,  0.17654037, ...,  0.03045904,
#          0.324237  , -0.05850488]], dtype=float32)

# %%
y1.shape
# Out:
# (1, 1568)

# %%
print("ha[]값 : x축값",ha)
# Out:
# ha[]값 : x축값 [0.525814, 0.17654037, -0.12980406, 0.29478252, 0.33366588, 0.4274923, -0.0049272277, -0.049032398, 0.28054154, 0.17860493, 0.3817898, 0.22840597, 0.17045625, -0.30713668, -0.22924024, 0.54541683, 0.22543114, -0.27066946, -0.2510117, -0.08791582, 0.8132534, 0.5979681, -0.40254825, 0.22919698, 0.31171823, 0.020154197, 0.36273605, 0.42016315, -0.4138297, -0.4361436, -0.23469295, 0.34894514, 0.12336601, 0.17017807, -0.58788687, 0.9294376, 0.6422879, 0.042095814, 0.105933115, -0.8831442, 0.105178826, -0.09811768, -0.23131211, -0.010326286, -0.16234675, 0.11016988, 0.5418684, -0.3204345, 0.019712968, 0.29724202, 0.4568128, 0.3915376, 0.51803744, -0.2726491, -0.5112673, 0.4722272, -0.123738, 0.03650704, 0.3780162, -0.28216785, 0.86935973, 0.05199262, 0.1025155, 0.10015738, -0.21776871, 0.13136017, 0.1968098, 0.42027667, -0.60709256, 0.392419, 0.33913612, 0.24838744, 0.21693829, 0.6627231, -0.4916272, 0.053119164, 0.09739341, 0.040473495, -0.23498157, 0.17001842, -0.042125806, 0
# ...

# %%
print("haha[]값 : y축값",haha)
# Out:
# haha[]값 : y축값 [-0.3396296, -0.28682435, -0.036202487, 0.3025214, -0.24240991, 0.4497392, -0.6258331, -0.3688755, 0.2125925, -0.44697696, 0.2832743, 0.14996924, -0.15372543, 0.055438094, 0.09891253, -0.1523508, -1.0121862, 0.1428244, 0.2150659, -0.16678259, -0.6211096, 0.2812268, 0.3128744, 0.20982878, 0.6225497, 0.27329078, -0.2692867, 0.17089464, -0.21296851, 0.32669142, -0.51572907, 0.018122314, -0.21967345, 0.28142807, -0.22801118, 0.8322131, 0.78500354, 0.16039793, -0.17302331, -0.0072454517, -0.19135681, 0.15997903, -0.346378, -0.31500113, 0.11871505, -0.36449707, -0.2714679, 0.07609764, -0.7113401, 0.037063465, 0.19007611, -0.0736711, 0.011527933, 0.5472539, 0.20752865, 0.21731138, 0.37978113, -0.040969756, -0.26332068, 0.09040659, -0.4372431, 0.3124812, 0.46204266, -0.042604726, -0.26301318, -0.21076956, -0.19230205, 0.39972156, 0.15493323, -0.73900765, -0.3700624, 0.248181, -0.33888528, 0.50727856, 0.11286552, 0.056355346, 0.060780987, -0.63701177, -0.57621497, -0.04340645, -
# ...

# %%
plt.plot(ha, haha) 
#stddev = 0.35가 되어 있다는 것을 대략적으로 확인할 수 있습니다.
